# %%
import openpyxl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#col = ['order', 'date', '1', '2', '3', '4', '5', '6', 'B']
col = ['order', 'date', 'number', 'bonus']
book = openpyxl.load_workbook("lotto.xlsx")
sheet = book.active
startPos = 'B4'
endPos = 'T' + str(sheet.max_row)
data_range = sheet[startPos:endPos]
data = []
for row in range(len(data_range)-1, -1, -1):
    values = []
    values.append(data_range[row][0].value)
    values.append(data_range[row][1].value)
    temp = []
    for n in range(12, 18):
        temp.append(data_range[row][n].value)
    values.append(temp)
    values.append(data_range[row][18].value)
    
    data.append(values)
    
print(data)
# Out:
# [[1, '2002.12.07', [10, 23, 29, 33, 37, 40], 16], [2, '2002.12.14', [9, 13, 21, 25, 32, 42], 2], [3, '2002.12.21', [11, 16, 19, 21, 27, 31], 30], [4, '2002.12.28', [14, 27, 30, 31, 40, 42], 2], [5, '2003.01.04', [16, 24, 29, 40, 41, 42], 3], [6, '2003.01.11', [14, 15, 26, 27, 40, 42], 34], [7, '2003.01.18', [2, 9, 16, 25, 26, 40], 42], [8, '2003.01.25', [8, 19, 25, 34, 37, 39], 9], [9, '2003.02.01', [2, 4, 16, 17, 36, 39], 14], [10, '2003.02.08', [9, 25, 30, 33, 41, 44], 6], [11, '2003.02.15', [1, 7, 36, 37, 41, 42], 14], [12, '2003.02.22', [2, 11, 21, 25, 39, 45], 44], [13, '2003.03.01', [22, 23, 25, 37, 38, 42], 26], [14, '2003.03.08', [2, 6, 12, 31, 33, 40], 15], [15, '2003.03.15', [3, 4, 16, 30, 31, 37], 13], [16, '2003.03.22', [6, 7, 24, 37, 38, 40], 33], [17, '2003.03.29', [3, 4, 9, 17, 32, 37], 1], [18, '2003.04.05', [3, 12, 13, 19, 32, 35], 29], [19, '2003.04.12', [6, 30, 38, 39, 40, 43], 26], [20, '2003.04.19', [10, 14, 18, 20, 23, 30], 41], [21, '2003.04.26', [6, 12, 17, 18
# ...

# %%
df_lotto = pd.DataFrame(data, columns=col)
#print(df)
df_lotto['date'] = pd.to_datetime(df_lotto['date'], format='%Y-%m-%d', infer_datetime_format=False, exact=True)
#print(df['date'])
print(df_lotto)
# Out:
#      order       date                    number  bonus
# 0        1 2002-12-07  [10, 23, 29, 33, 37, 40]     16
# 1        2 2002-12-14   [9, 13, 21, 25, 32, 42]      2
# 2        3 2002-12-21  [11, 16, 19, 21, 27, 31]     30
# 3        4 2002-12-28  [14, 27, 30, 31, 40, 42]      2
# 4        5 2003-01-04  [16, 24, 29, 40, 41, 42]      3
# 5        6 2003-01-11  [14, 15, 26, 27, 40, 42]     34
# 6        7 2003-01-18    [2, 9, 16, 25, 26, 40]     42
# 7        8 2003-01-25   [8, 19, 25, 34, 37, 39]      9
# 8        9 2003-02-01    [2, 4, 16, 17, 36, 39]     14
# 9       10 2003-02-08   [9, 25, 30, 33, 41, 44]      6
# 10      11 2003-02-15    [1, 7, 36, 37, 41, 42]     14
# 11      12 2003-02-22   [2, 11, 21, 25, 39, 45]     44
# 12      13 2003-03-01  [22, 23, 25, 37, 38, 42]     26
# 13      14 2003-03-08    [2, 6, 12, 31, 33, 40]     15
# 14      15 2003-03-15    [3, 4, 16, 30, 31, 37]     13
# 15      16 2003-03-22    [6, 7, 24, 37, 38, 40]     33
# ...

# %%
lotto = df_lotto['number']
lottob = df_lotto[['number', 'bonus']]
print(lotto)
#print(lottob)
# Out:
# 0      [10, 23, 29, 33, 37, 40]
# 1       [9, 13, 21, 25, 32, 42]
# 2      [11, 16, 19, 21, 27, 31]
# 3      [14, 27, 30, 31, 40, 42]
# 4      [16, 24, 29, 40, 41, 42]
# 5      [14, 15, 26, 27, 40, 42]
# 6        [2, 9, 16, 25, 26, 40]
# 7       [8, 19, 25, 34, 37, 39]
# 8        [2, 4, 16, 17, 36, 39]
# 9       [9, 25, 30, 33, 41, 44]
# 10       [1, 7, 36, 37, 41, 42]
# 11      [2, 11, 21, 25, 39, 45]
# 12     [22, 23, 25, 37, 38, 42]
# 13       [2, 6, 12, 31, 33, 40]
# 14       [3, 4, 16, 30, 31, 37]
# 15       [6, 7, 24, 37, 38, 40]
# 16        [3, 4, 9, 17, 32, 37]
# 17      [3, 12, 13, 19, 32, 35]
# 18      [6, 30, 38, 39, 40, 43]
# 19     [10, 14, 18, 20, 23, 30]
# 20      [6, 12, 17, 18, 31, 32]
# 21         [4, 5, 6, 8, 17, 39]
# 22      [5, 13, 17, 18, 33, 42]
# 23       [7, 8, 27, 29, 36, 43]
# 24       [2, 4, 21, 26, 43, 44]
# 25        [4, 5, 7, 18, 20, 25]
# 26      [1, 20, 26, 28, 37, 43]
# 27      [9, 18, 23, 25, 35, 37]
# 28       [1, 5, 13, 34, 39, 40]
# ...

# %%
nlotto = np.array([lotto])
# total sum
print(nlotto)
#print(nlotto.reshape(-1))
nlotto = nlotto.reshape(-1)
print(nlotto)
nlotto = nlotto.reshape(int(len(nlotto)/6), 6)
print(nlotto)
nlotto_sum = np.sum(nlotto)
print(nlotto_sum)
# Out:
# [[[10 23 29 33 37 40]
#   [9 13 21 25 32 42]
#   [11 16 19 21 27 31]
#   ...
#   [14 15 25 28 29 30]
#   [16 25 33 38 40 45]
#   [10 21 22 30 35 42]]]
# [10 23 29 ... 30 35 42]
# [[10 23 29 33 37 40]
#  [9 13 21 25 32 42]
#  [11 16 19 21 27 31]
#  ...
#  [14 15 25 28 29 30]
#  [16 25 33 38 40 45]
#  [10 21 22 30 35 42]]
# 112839

# %%
# avrage of each orders
nlotto_avg = np.average(nlotto, axis=1)
#print(nlotto_avg)
nlotto_t = np.transpose(nlotto)
#print(nlotto_r)
nlotto_avg_t = np.average(nlotto_t, axis=1)
#print(nlotto_avg_t)
df = pd.DataFrame(nlotto_avg)
#print(df)

# %%
#nlotto1g = np.array([lotto['1']+45])
#nlotto = np.hstack((nlotto, nlotto1.T))
#nlotto = np.concatenate((nlotto, nlotto1g.T), axis=1)

# difference of each numbers
nlotto_gap = np.diff(nlotto, axis=1)
df = pd.DataFrame(nlotto_gap)
print(nlotto_gap)
# Out:
# [[13 6 4 4 3]
#  [4 8 4 7 10]
#  [5 3 2 6 4]
#  ...
#  [1 10 3 1 1]
#  [9 8 5 2 5]
#  [11 1 8 5 7]]

# %%
# avrage of difference of each numbers
nlotto_gap_avg = np.average(np.array(nlotto_gap), axis=1)
df = pd.DataFrame(nlotto_gap_avg)

print(df)
# Out:
#        0
# 0      6
# 1    6.6
# 2      4
# 3    5.6
# 4    5.2
# 5    5.6
# 6    7.6
# 7    6.2
# 8    7.4
# 9      7
# 10   8.2
# 11   8.6
# 12     4
# 13   7.6
# 14   6.8
# 15   6.8
# 16   6.8
# 17   6.4
# 18   7.4
# 19     4
# 20   5.2
# 21     7
# 22   7.4
# 23   7.2
# 24   8.4
# 25   4.2
# 26   8.4
# 27   5.6
# 28   7.8
# 29   7.2
# ..   ...
# 790    8
# 791  6.8
# 792  6.6
# 793  6.4
# 794    7
# 795    8
# 796    8
# 797  6.8
# 798  6.6
# 799  8.8
# 800  5.4
# 801  6.4
# 802  7.6
# 803    7
# 804  5.8
# 805  4.8
# 806  5.8
# 807  5.6
# 808  6.8
# 809  7.6
# 810  7.4
# 811  8.4
# 812  6.6
# 813  8.6
# 814  3.8
# 815  5.4
# 816    8
# 817  3.2
# 818  5.8
# 819  6.4
#
# [820 rows x 1 columns]

# %%
from datetime import datetime

# lotto numbers
numbers = np.linspace(1, 45, 45, dtype=int)
num_count = []
count = 0
# dates for numbers
dic_num = {key: [] for key in numbers}

for n in numbers:
    for index, row in df_lotto.iterrows():
        for k in row['number']:
            if n == k:
                #print(row['date'])
                dic_num[n].append(row['date'].strftime('%Y-%m-%d'))
                count+=1
    num_count.append(count)
    count = 0

print(num_count)
# Out:
# [118, 108, 109, 112, 113, 105, 111, 113, 82, 118, 114, 117, 113, 116, 113, 102, 119, 114, 113, 121, 110, 89, 98, 108, 108, 109, 124, 97, 99, 98, 112, 94, 111, 130, 102, 109, 116, 103, 108, 122, 101, 103, 116, 107, 115]

# %%
# 번호별 나온 횟수
fig, ax = plt.subplots()
rects1 = ax.bar(numbers, num_count, 0.8,
                color='SkyBlue', label='number')
plt.show()

# %%
df_num_1 = pd.DataFrame(dic_num[1])
print(df_num_1)
# Out:
#               0
# 0    2003-02-15
# 1    2003-06-07
# 2    2003-06-21
# 3    2003-08-09
# 4    2003-10-11
# 5    2003-12-13
# 6    2004-05-15
# 7    2004-06-26
# 8    2004-08-07
# 9    2004-08-28
# 10   2004-10-02
# 11   2004-10-23
# 12   2004-10-30
# 13   2004-11-06
# 14   2004-12-18
# 15   2005-01-01
# 16   2005-02-12
# 17   2005-04-02
# 18   2005-10-22
# 19   2005-10-29
# 20   2005-12-17
# 21   2006-01-07
# 22   2006-04-22
# 23   2006-04-29
# 24   2006-06-10
# 25   2006-06-17
# 26   2006-07-01
# 27   2006-10-21
# 28   2006-11-04
# 29   2006-11-11
# ..          ...
# 88   2013-10-19
# 89   2013-11-02
# 90   2014-07-05
# 91   2014-07-12
# 92   2014-10-25
# 93   2014-11-15
# 94   2014-12-13
# 95   2015-01-03
# 96   2015-04-11
# 97   2015-11-07
# 98   2015-11-14
# 99   2016-01-09
# 100  2016-01-30
# 101  2016-03-12
# 102  2016-04-02
# 103  2016-05-28
# 104  2016-06-04
# 105  2016-08-06
# 106  2016-09-17
# 107  2016-09-24
# 108  2016-10-29
# 109  2017-03-11
# 110  2017-04-15
# ...

# %%
plt.figure(figsize=(20,10))
plt.ylabel('number')
#plt.ylim(0, 46)
x_start = df_lotto['date'].values[0]
x_end = df_lotto['date'].values[-1]

#nlottoT = nlotto.T
nlottoT = np.array([df_lotto['number']]).T

plt.axis([x_start, x_end, 0, 46])

plt.plot(df_lotto['date'], nlottoT[0], '-')
plt.plot(df_lotto['date'], nlottoT[1], '-')
plt.plot(df_lotto['date'], nlottoT[2], '-')
plt.plot(df_lotto['date'], nlottoT[3], '-')
plt.plot(df_lotto['date'], nlottoT[4], '-')
plt.plot(df_lotto['date'], nlottoT[5], '-')

plt.xticks(rotation='vertical')

plt.show()

# %%
print(df.columns)
